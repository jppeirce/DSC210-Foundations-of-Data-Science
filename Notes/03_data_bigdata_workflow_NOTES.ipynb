# %% [markdown]
# # Module 2: What Is Data? Big Data and the Data Science Workflow
#
# **DSC 210 Foundations of Data Science**
#
# *References:
# - [Hands-on Introduction to Data Science with Python](https://florian-huber.github.io/data_science_course/) (CC BY-NC-SA 4.0), and
# - Palmer Penguins (Horst, Hill, and Gorman, 2020; CC0).*
#
# ## Learning objectives
#
# 1. Define data and distinguish **structured** from **unstructured** data, using the vocabulary of **cases**, **features**, and **metadata**.
# 2. Classify a variable by measurement scale (nominal, ordinal, interval, ratio) and say which operations it permits.
# 3. Explain what makes data big and why that matters for data science.
# 4. Trace the Data -> Information -> Knowledge progression and connect it to "inference to the best explanation."
# 5. Describe a **data science workflow** and locate its steps on our course loop.

# %% [markdown]
# ## The spine of this course
#
# Today we name the thing the whole course hangs on. Every technique you will learn lives somewhere on one repeating loop:
#
# ```
# ASK  ->  GET  ->  EXPLORE  ->  MODEL  ->  COMMUNICATE
#  ^                                            |
#  |________ findings raise new questions _______|
# ```
#
# This course is **not** a list of Python tricks. It is one loop, walked many times on many datasets, always asking who the data is about and who our answer affects. From this module on, each notebook opens by marking **where on the loop we are**.
#
# Today's questions, *What is data? What makes data "big"? How do we go from raw data to knowledge?*, are the groundwork for the whole loop, so today we stand at the very start: **ASK / GET**.

# %% [markdown]
# ## Setup
#
# We keep one small real dataset on screen to make the abstract vocabulary concrete: **Palmer Penguins**, body measurements for 344 penguins near Palmer Station, Antarctica. It ships with `seaborn`, so there is nothing to download.

# %%
# RUN-TOGETHER
import seaborn as sns
import pandas as pd

penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
# ---------------------------------------------------------------------------
#
# AttributeError                            Traceback (most recent call last)
#
# Cell In[4], line 2
#
#       1 # RUN-TOGETHER
#
# ----> 2 import seaborn as sns
#
#
#
# File ~/Library/CloudStorage/OneDrive-UniversityofWisconsin-LaCrosse/Courses/210Intro2DS/DSC210 Foundations of Data Science/.venv/lib/python3.12/site-packages/seaborn/__init__.py:2
#
#       1 # Import seaborn objects
#
# ----> 2 from .rcmod import *  # noqa: F401,F403
#
#       3 from .utils import *  # noqa: F401,F403
#
#       4 from .palettes import *  # noqa: F401,F403
#
#
#
# File ~/Library/CloudStorage/OneDrive-UniversityofWisconsin-LaCrosse/Courses/210Intro2DS/DSC210 Foundations of Data Science/.venv/lib/python3.12/site-packages/seaborn/rcmod.py:5
#
#       3 import matplotlib as mpl
#
#       4 from cycler import cycler
#
# ----> 5 from . import palettes
#
#       8 __all__ = ["set_theme", "set", "reset_defaults", "reset_orig",
#
# ...

# %% [markdown]
# ## 1. What is (are?) data?
#
# A working definition: **data is information recorded through observation or measurement.** That is deliberately broad, because data has taken wildly different physical forms across history:
#
# - tally marks carved on bone,
# - London parish death records,
# - readings streamed from a wearable fitness device,
# - every post on a social media platform.
#
# *(Aside: whether "data" is singular or plural is genuinely contested. We will not settle it today.)*

# %% [markdown]
# > **Discuss (think-pair-share, ~3 min).** Name one source of data that did **not** exist 30 years ago, and one that has existed for centuries. For each, what is being *observed or measured*? Keep your two examples; we return to them when we discuss big data.

# %% [markdown]
# ## 2. The vocabulary of a dataset
#
# Three terms we will use all semester. Rather than define them in the abstract, we will read them straight off the penguins table.
#
# - **Structured data:** organized in a defined format, typically rows and columns (a spreadsheet, a `.csv`, a database). The penguins table is structured.
# - **Unstructured data:** no fixed row/column form: raw text, images, audio, video.
#
# Within a structured (tabular) dataset:
#
# - **Features** are the columns: the properties measured (also called variables or attributes).
# - **Cases** are the rows: the units observed (also called records, units, or subjects).
# - **Metadata** is data *about* the data: where it came from, when, how it was collected, its units and quality.

# %% [markdown]
# > **Predict, then run.** In the penguins table, the rows are individual penguins and the columns are things measured about them. **Before running the next cell**, predict: how many **cases** (rows) and how many **features** (columns) are there?
#
# My prediction: ____ cases, ____ features.

# %%
# RUN-TOGETHER
n_cases, n_features = penguins.shape
print('cases (rows)   :', n_cases)
print('features (cols):', n_features)

print('the feature names:')
print(list(penguins.columns))

# %% [markdown]
# Now let's look at a **single case**: one penguin, and all of its feature values. This is what "a row is one unit of observation" means in practice.

# %%
# FILL-IN-LIVE
# Goal: pull out the very first case (one penguin) and see all its feature values.
# together: which position selects the FIRST row? Change the number below.
row_position = 0    # <-- fill in live (0 = first case)

first_case = penguins.iloc[row_position]
print(first_case)

# %% [markdown]
# > **Discuss.** The penguins table is *structured*. What would the **unstructured** version of penguin data look like? (Think: what did a field researcher actually record before it became this tidy table?) Who decided which measurements became columns, and what got left out? *Hold that last question; it returns in the ethics thread.*

# %% [markdown]
# ## 3. Not all features are the same: measurement scales
#
# A feature's **measurement scale** determines which operations are even meaningful on it. This is a bridge straight from your statistics course.
#
# | Scale | Characteristics | Permissible operations | Example |
# | --- | --- | --- | --- |
# | **Nominal** | unordered categories | count, mode | penguin species, island |
# | **Ordinal** | ordered, unequal gaps | median, percentiles | survey rating (poor/fair/good) |
# | **Interval** | equal gaps, no true zero | mean, standard deviation | temperature (C) |
# | **Ratio** | equal gaps, true zero | all arithmetic, ratios | flipper length, body mass |
#
# The payoff, stated plainly: **the scale decides which summary is legal.** Averaging a species label is not just bad style; it is a category error.

# %% [markdown]
# > **Predict, then run.** Consider two penguin features: `species` (Adelie, Chinstrap, Gentoo) and `body_mass_g`. For which one does asking for a **mean** make sense? Predict, then we test both.

# %%
# RUN-TOGETHER
# Ratio feature: a mean is meaningful.
print('mean body mass:', round(penguins['body_mass_g'].mean(), 1), 'g')

# %%
# RUN-TOGETHER
# Nominal feature: what is the RIGHT summary? Not a mean, but a count.
print(penguins['species'].value_counts())

# %% [markdown]
# > **Discuss.** `body_mass_g` is stored as a number, and so is a US ZIP code, yet averaging ZIP codes is meaningless. What distinguishes a feature you may average from one you may not? (This is the scale idea, in your own words.)

# %% [markdown]
# ## 4. What makes data "big"?
#
# **Big data:** data that is too large, too complex, or too fast-changing to handle manually or with traditional methods. The penguins table (344 rows) is emphatically **not** big; you could inspect it by hand. Bigness is usually described by a set of **V's**:
#
# - **Volume:** sheer quantity (terabytes, petabytes).
# - **Velocity:** how fast it arrives (a sensor stream, a live feed).
# - **Variety:** many forms at once (text + images + numbers).
# - **Veracity:** how trustworthy or noisy it is.
#
# *(Different authors list three, four, or five V's. The exact count is not important; the dimensions are.)*

# %% [markdown]
# > **Discuss (think-pair-share).** Return to the two data sources you named in Section 1. For each, rate it low/medium/high on **Volume** and on **Velocity**. Does either one qualify as "big"? What specifically makes traditional, by-hand analysis break down for it?

# %% [markdown]
# Why this matters for the course: the *reason* data science emerged as a field is that bigness broke the old tools. When you cannot eyeball the data or fit it in a spreadsheet, you need code, statistics, and algorithms working together. That is the whole motivation for learning the workflow we are about to name.

# %% [markdown]
# ## 5. From data to knowledge
#
# Raw data by itself is often meaningless. A widely used ladder describes how meaning gets added:
#
# - **Data:** raw values or findings. Unprocessed reality; possibly incomprehensible on its own. *(The number `181`.)*
# - **Information:** data placed in context, structured and categorized. *(`181` is a flipper length in millimeters.)* Otte et al. (2020): "information is data with potential significance for a user."
# - **Knowledge:** understanding built from information, combining facts, theories, and experience. *(Adelie penguins tend to have shorter flippers than Gentoos, and here is why that might be.)*
#
# This is sometimes drawn as a pyramid with **Wisdom** at the top (knowing which questions are worth asking at all).

# %% [markdown]
# Huber frames the same progression with a memorable analogy: **the data scientist as detective.**
#
# - Data are **clues**.
# - Clues pieced together become a **story** (information).
# - Story plus context becomes an **informed conclusion** about the truth (knowledge).
#
# The detective does not passively receive the answer; they *reason* toward the best explanation of the clues.

# %% [markdown]
# **Inference to the best explanation** (Bartelborth, 2017) makes that reasoning explicit, and, not coincidentally, it previews our workflow:
#
# 1. **Observe** the phenomena (gather the raw data / clues).
# 2. **Formulate hypotheses** that might explain them.
# 3. **Refine:** discard hypotheses that do not fit the facts.
# 4. **Compare:** which surviving hypothesis explains the data best?
# 5. **Select** the most plausible, comprehensive explanation.
#
# > **Discuss.** A detective and a data scientist both reason from clues to the best explanation. Name one way the two jobs genuinely differ. (Consider: volume of clues, the role of chance/uncertainty, reproducibility.)

# %% [markdown]
# ## 6. The data science workflow (the spine, formally)
#
# A **workflow** is a blueprint that guides a project from question to communicated result. Several standard ones exist:
#
# - **CRISP-DM** (circular): Business Understanding, Data Understanding, Data Preparation, Modeling, Evaluation, Deployment.
# - **OSEMN** (linear): Obtain, Scrub, Explore, Model, iNterpret.
# - **Tree-like** workflows branch after a step into multiple paths.
#
# Huber's text uses a tailored six-phase version, **ASEMIC**:
#
# **A**cquire, **S**crub, **E**xplore, **M**odel, **I**nterpret, **C**ommunicate.
#
# Huber stresses, and we agree, that this is **iterative, not linear**: after modeling you often return to scrubbing; after interpreting you may revisit exploration.

# %% [markdown]
# ### Reconciling ASEMIC with our course loop
#
# We will use a five-stage loop as the course **spine** because it is easy to hold in your head and it makes the iteration visible. Huber's ASEMIC is the same process at finer grain. Here is the crosswalk, so the two never confuse you:
#
# | Course loop (our spine) | Huber's ASEMIC | In plain words |
# | --- | --- | --- |
# | **ASK** | *(the overarching question)* | What are we trying to find out? |
# | **GET** | **A**cquire | Obtain and inspect the raw data |
# | **EXPLORE** | **S**crub + **E**xplore | Clean it; visualize; find patterns |
# | **MODEL** | **M**odel | Describe or predict |
# | **COMMUNICATE** | **I**nterpret + **C**ommunicate | Decide what it means; share it |
#
# Both are loops. Findings at the end feed new questions at the start. The one idea to carry away: **real data science is cyclical.** You will walk this loop many times before the semester ends.

# %% [markdown]
# > **Discuss (whole class).** Take the opening question of the course, *"who is most likely to attend a concert in La Crosse?"* (from Module 1). Without solving it, name what the **GET** stage and the **COMMUNICATE** stage would each involve for that question. Where might the loop send you *backward*?

# %% [markdown]
# ## 7. First stop on the loop: acquiring data (GET)
#
# Since GET is where every project begins, four questions to ask of any dataset before you trust it:
#
# 1. **Type of data needed:** quantitative or qualitative? temporal? spatial? What would actually answer the question?
# 2. **Quality and quantity:** enough breadth and depth? gaps? inconsistencies?
# 3. **Sources:** available, accessible, and *trustworthy*?
# 4. **Usage restrictions:** any legal, commercial, or privacy limits? **Having data is not the same as being allowed to use it.**
#
# Common sources include public data portals (Kaggle, Zenodo, the UCI repository), web scraping (within legal and ethical limits), internal corporate data, academic datasets attached to papers, data on request, and commercial datasets.

# %% [markdown]
# ### Guided activity: plan a data acquisition (~10 min)
#
# *This is the interactive core of the unit. Work in groups; we will collect answers as a class.*
#
# **Scenario.** You are asked to evaluate the state of **digitization in schools** in our region. Objective: assess the current level of digital infrastructure and how it is used.
#
# Brainstorm and record notes in the code cell below:

# %%
# Group notes (write responses as comments)
#
# (1) What kinds of data would you need? (list 4-6)
#   -
#   -
#
# (2) Where could you source each one?
#   -
#   -
#
# (3) What roadblocks might you hit? (access, privacy, format, bias)
#   -
#   -

# %% [markdown]
# > **Debrief (whole class).** As groups report out, sort their roadblocks into our loop: which are **GET** problems (access, permission), which are **EXPLORE** problems (missing, inconsistent, messy), and which are **ethics** problems (privacy, FERPA, consent) that run *underneath every stage*? This sorting is the point of the exercise.

# %% [markdown]
# ## Summary
#
# - **Data** is recorded observation or measurement; it may be **structured** (rows and columns) or **unstructured** (text, images, audio).
# - In a table: **cases** are rows, **features** are columns, **metadata** is data about the data.
# - A feature's **measurement scale** (nominal / ordinal / interval / ratio) decides which summaries are meaningful.
# - **Big data** (Volume, Velocity, Variety, Veracity) is what broke the old tools and motivated data science as a field.
# - **Data -> Information -> Knowledge**: meaning is added by context and reasoning; the data scientist reasons like a detective toward the best explanation.
# - The **workflow** is our course **spine**: ASK -> GET -> EXPLORE -> MODEL -> COMMUNICATE, an iterative loop. Huber's **ASEMIC** is the same process at finer grain, and ethics runs underneath all of it.
#
# **Next module (GET, continued): Tables of Data with pandas**, where we stop reading vocabulary off a table and start manipulating the whole table ourselves.

# %% [markdown]
# ## References
#
# - Huber, F. *Hands-on Introduction to Data Science with Python* (ch. on data, DIKW, and the ASEMIC workflow). https://florian-huber.github.io/data_science_course/
# - Huber, F. *Waterfalls or trapped in loops: the data science workflow(s)* (Medium), on ASEMIC and its iterative nature.
# - Bartelborth, T. (2017), on inference to the best explanation (as cited in the source lecture material).
# - Otte et al. (2020); Rowley (2007); Zins (2009), on the Data-Information-Knowledge progression (as cited in the source material). **Flagged:** verify these secondary citations against the originals before distributing to students.
# - Horst, A. M., Hill, A. P., and Gorman, K. B. (2020). *palmerpenguins* (CC0). https://allisonhorst.github.io/palmerpenguins/
