# %% [markdown]
# <a href="https://colab.research.google.com/github/jppeirce/DSC210-Foundations-of-Data-Science/blob/main/Notes/03-intro_to_python/03-Intro_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 3: Introduction to Python
#
# **DSC 210 Foundations of Data Science**
#
# References:
# - [Hands-on Introduction to Data Science with Python](https://florian-huber.github.io/data_science_course/) (CC BY-NC-SA 4.0), and
#
# ## Learning objectives
#
# 1. Use Python as a calculator and store results in variables.
# 2. Recognize and choose the core value types: `int`, `float`, `str`, `bool`.
# 3. Build, index, slice, and safely copy lists.
# 4. Call functions and methods, and read `help()`.
# 5. Import and use packages.

# %% [markdown]
# ---
# ## 1. Values, Variables, and Types (Oh My!)
# ---

# %%
# RUN-TOGETHER
# Python as a calculator
# Anything after a '#' is a comment and is ignored by Python.

# Press Command + Return (Mac) or Control + Enter (PC) to run this code cell.
print(5 / 8)
print(4 + 5)
print(2 ** 10)   # ** means 'to the power of'

# %%
# RUN-TOGETHER
# We can also use basic arithmetic operations
# Addition and division
4 + 5
print(10 / 2)
# Note: Python notebook code chunks (what this) only displays the
# result of last calculation

# %% [markdown]
# ### Activity 1 - Python as a calculator
#
# In a new code print the following calculations
#
# a. Subtract 2 from 8
#
# b. Multiply 2 by 8
#
# c. Divide 8 by 2
#
# *Note:* To create a new code chunk, hover the cursor between cells and select + Code

# %% [markdown]
# ### Activity 1 conitnued - Hmmm...that is interesting?
#
# Why do you think that the formating of last two answers, 16 vs. 4.0, are different?

# %% [markdown]
# ### Variable Assignment
#
# A variable lets us refer to a value by a name. We create one with `=`.
#
# **Definition** The command `x = 5` is an *assignment action*: "let the name `x` refer to the value `5`." It is **not** a claim that x equals 5. This is an important shift from math notation, where `=` states a fact. In Python, `=` *does* something.

# %%
# Example - RUN-TOGETHER
# Create a variable savings with the value of 100.
savings = 100
# Check out this variable.
print(savings)

# %% [markdown]
# ### Class Example: Savings over time
#
# > **Predict first.** You start with \$100 and save \$10 per month. How much after 4 months? Predict, then we compute it together.

# %%
# RUN-TOGETHER
# Suppose you start with $100 in savings.
# How much money would you have saved four months from now,
# if you saved $10 each month?

initial_savings = 100
monthly_savings = 10
months = 4

total_savings = initial_savings + monthly_savings * months
print(total_savings)

print(100+10*4)

# %% [markdown]
# > **Discussion.** Why write `initial_savings`, `monthly_savings`, `months` instead of just typing `100 + 10 * 4`?
#
# This is the difference between a *calculation* and a *model*.

# %% [markdown]
# ## The four core variable types
#
# Every value stored in Python has a **type**. Four value types show up constantly.
#
# **Definition.**
#
# | Type | Name | Example | A penguin feature |
# | --- | --- | --- | --- |
# | `int` | whole number | `100` | number of penguins |
# | `float` | decimal | `18.7` | bill depth (mm) |
# | `str` | text | `'Adelie'` | species |
# | `bool` | True / False | `True` | is it an adult? |
#
# The `type()` function tells you which one you have.

# %%
# RUN-TOGETHER
print(type(100))          # int
print(type(18.7))         # float
print(type('Adelie'))     # str
print(type(True))         # bool

# %% [markdown]
# # Other variable types
# In the previous exercise, you worked with the integer Python data type `int`, or integer: a number without a fractional part. savings, with the value 100, is an example of an integer.
#
# Next to numerical data types, there are three other very common data types/classes:
#
# * `float`, or floating point: a number that has both an integer and fractional part, separated by a point. 1.1, is an example of a float.
# * `str`, or string: a type to represent text. You can use single or double quotes to build a string.
# * `bool`, or boolean: a type to represent logical values. It can only be True or False (the capitalization is important!).

# %% [markdown]
# ### Example 1.2: Types have different behavior
#
# The type controls what an operation *means*. Watch `+` do two totally different things:

# %%
# RUN-TOGETHER
print(3 + 4)              # numbers: arithmetic -> 7
print('Adelie' + 'Penguin')  # strings: glued together (concatenation)
print('ha' * 3)           # string times int: repetition

# %% [markdown]
# > **Predict, then run.** What will each of these do, a value or an error? Decide with your neighbor first.
#
# - `'3' + '4'`  -> ____
# - `True + True` -> ____
# - `'3' + 4`    -> ____
#
# Then, test your answers by uncommenting each line of code:

# %%
# RUN-TOGETHER
print('3' + '4')
# print(True + True)
# print('3' + 4)

# %%
### Activity 2 - Predict type AND value for each, THEN run.
print(type(15 / 3), 15 / 3)
# The command b // a gives the (whole) number of times a divides into b
print(type(10 // 3), 10 // 3)
print(type('pen' + 'guin'), 'pen' + 'guin')
print(type(5 < 3), 5 < 3)
print(type(2 ** 0.5), 2 ** 0.5)  # square root of 2

# %% [markdown]
# ---
# ## 2. Lists, Functions, and Methods
# ---

# %% [markdown]
# ## Lists: Holding many values
#
# A single variable holds one value. A **list** holds an ordered collection, and a list is our first stand-in for *a column of data*.
#
# **Definition.** A *list* is an ordered, changeable sequence of values, written in square brackets and separated by commas.

# %%
# RUN-TOGETHER
# Bill lengths (mm) for the first six penguins in the dataset.
bill_lengths = [39.1, 39.5, 40.3, 36.7, 39.3, 38.9]
print(bill_lengths)

# %% [markdown]
# ## Indexing and slicing
#
# We reach into a list by position or index. Python counts from **0**, not 1.
#
# - `x[0]` is the first element, `x[1]` the second.
# - `x[-1]` is the last element (negative counts from the end).
# - `x[start:stop]` is a **slice**: from `start`, up to but **not including** `stop`.

# %%
# RUN-TOGETHER
bill_lengths = [39.1, 39.5, 40.3, 36.7, 39.3, 38.9]
print(bill_lengths[0])    # first  -> 39.1
print(bill_lengths[-1])   # last   -> 38.9
print(bill_lengths[0:3])  # first three -> [39.1, 39.5, 40.3]
print(bill_lengths[:3])

# How do slice out the middle two values:
print(bill_lengths[___:___])

# %% [markdown]
# ### Activity 3 - Predict, then run.
# The list has 6 elements (positions 0 to 5). Predict each slice before running.
#
# - `bill_lengths[2:5]` -> ____
# - `bill_lengths[:2]`  -> ____
# - `bill_lengths[3:]`  -> ____

# %% [markdown]
# ## A list within a list
#
# We can also constuct lists of lists (when could this be helpful?)

# %%
# RUN-TOGETHER
# Example - Areas of rooms in a house

hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

# House area information as list of lists
house = [["hallway", hall],
         ["kitchen", kit],
         ["living room", liv],
         ["bedroom", bed],
         ["bathroom", bath]]
# Print areas
print(house)

# %%
# Note: house[0] returns the first element of the list house, which is itself a list.
print("first list:", house[0])
# We can access the elements of that list using another index.
print("first element of first list:", house[0][0])
print("second element of first list:", house[0][1])

# %% [markdown]
# ### Activity 4 - House Info
# Create code to find the value in the last row and column of `house` (list of lists)
#
# Recall, the format is `list[row index][column index]`

# %%
print(house[-1][-1])
print(house[4][1])
print(house[-1][1])

# %% [markdown]
# ## Editing a list

# %%
# Example - List Editing

high_temp = [83, 85, 91.5, 88, 89.5]
print(high_temp)
high_temp_new = high_temp + [92.0, 43]
print(high_temp_new)

# We can all do this with the list method append() instead of creating a new list.
high_temp.append(92.0)
print(high_temp)

# %%
# FILL IN TOGETHER
# Delete the 3rd element of the list
print(high_temp)
del high_temp[___]
print(high_temp)

# %% [markdown]
# ## The copy trap (aliasing)
#
# In data work, accidentally altering your dataset is hard to notice. A common silent bug for new Python users, is creating a alias instead of copy.
#
# Writing `b = a` for a list does **not** make a copy; it makes a second name for the *same* list.

# %%
# RUN-TOGETHER
original = [1, 2, 3, 4]
alias = original          # NOT a copy: same list, two names
alias.append(99)

print('alias   :', alias)
print('original:', original)

# Keep this in mind especially dealing with raw (original) data

# %%
# RUN-TOGETHER
# The fix: make a real copy with list(...) or a full slice [:]
original = [1, 2, 3, 4]
real_copy = original.copy()    # independent copy
real_copy.append(99)

print('real_copy:', real_copy)
print('original :', original)

# %% [markdown]
# ## Functions
#
# **Definition.** A *function* is a reusable code block you call by name for a specific tasl.
#
# You have already used built-in functions `print()` and `type()`. Functions take **arguments** inside the parentheses and often return a result.

# %%
# RUN-TOGETHER
bill_lengths = [39.1, 39.5, 40.3, 36.7, 39.3, 38.9]
print('count  :', len(bill_lengths))
print('largest:', max(bill_lengths))
print('smallest:', min(bill_lengths))
print('sum    :', sum(bill_lengths))
print('rounded avg:', round(sum(bill_lengths) / len(bill_lengths), 2))

# %% [markdown]
# ## Example - I need help.
#
# Use help(foo) or ?foo to see information about a function

# %%
# Example - Help Function
? pow

print(pow(2,3))
print(2**3)

# Note the required and optional arguments

# %%
##Example - Help Function

# Create lists first and second
first = [11.25, 18.0, 20.0]
second = [10.75, 9.50]

# Combine the two lists, and use the function `sorted()`
# to arrange the values in decreasing order

? sorted

all = first + second #put them together in one list
sorted(all, reverse=True)

# %% [markdown]
# # Functions and Methods
#
# - Everything in Python is an *object*, including strings, floats, and lists
#
# **Definition.** *Methods* are functions that belong to Python objects.
#
#     - Methods with the same name can behave differently based on the object type.
#     - Some methods can modify the objects they're called on.

# %%
# Example - Dot Notation
# RUN-TOGETHER
species = 'gentoo'

# Suppose we want to capitalize species. Does this work?

capitalize(species)

# %%
# Instead, to call the method `capitalize()`, we use "dot notation":

print( species.capitalize() ) # Call method capitalize() on species

# The method 'capitolize()' belongs to all string objects
# It is automatically included when the object is created

print( species.upper() )

# Some methods take inputs. For example, with the list object:
nums = [3, 1, 4, 1, 5]
print(nums.count(1))          # list method: how many 1s?
print(nums.index(1))          # position of first 1
nums.append(42)
print(nums)

# %%
## Example - Dot Notation
# RUN-TOGETHER
# Depending on the object type, the method may behave differently
species = "gentoo"
print(species.index("t"))
print(species.count("o"))

# It seems like the string species is stored as a list of characters:
# species = ['g', 'e', 'n', 't', 'o', 'o']

# %%
## Activity - List Methods
# Here are sample of the penguin masses (in grams) stored as a list:
masses = [375, 380, 325, 370, 345, 365, 380, 570]

# A. Use the length function len() to print the number of
# penguins in the sample.


# B. Use the index method to print the index of the element 365


# C. Print out how often 380 appears in masses


# D. Use the append method to add a new penguin mass of 425 grams


# E. Use the reverse method to reverse the orders of the elements in
# masses


# F. Complete the following:

## Find the lightest and heaviest penguins in the sample:
print('lightest:', min(masses))
print('heaviest:', ____ )      # fill in

## Find the sample mean of mass.
print('mean:', round(sum(masses) / ____ , 1)) # fill in

## Slice out the first three penguins:
print('first three:', masses[____] )   # fill in

# %% [markdown]
# ---
# # 3. Packages
# ---

# %% [markdown]
# # Packages
#
# What about other methods? Something a little more niche/nuanced/specialized?
#
# Not everybody needs all of the functions or methods that are available, so these are not included in Python distributions
#
# This is where *packages* come in!
#
# The data science stack
#
# ```
# ASK  ->  GET  ->  EXPLORE  ->  MODEL  ->  COMMUNICATE
#  ^                                            |
#  |________ findings raise new questions ______|
# ```
#
# has a few you will use constantly:
#
# | Package | Gives us | Used in |
# | --- | --- | --- |
# | `numpy` | fast numeric arrays | storing data (GET) |
# | `matplotlib` / `seaborn` | data visulization | (EXPLORE) |
# |`scikit-learn`| machine learning tools | (MODEL)
#
#
# **Note:** depending on how you access Python (cloud versions, local versions), you may need to manually download packages before installing.

# %% [markdown]
# ## Installing Packages
#
# **Note:** depending on how you access Python (cloud versions, local versions), you may need to manually download packages before installing. See this link for instructions if needed.
#
# (https://packaging.python.org/en/latest/tutorials/installing-packages/)[https://packaging.python.org/en/latest/tutorials/installing-packages/]
#
# In something like Jupyter Notebooks (via Google Colab, etc.), many common packages are already available.

# %% [markdown]
# ## Importing Packages
# Before we can start using modules and methods from packages, we need to import the package (or specific module from the package).
#
# We can do this with an `import` statement, like:
#
# `import numpy`

# %%
# Example - Importing Packages
# Use the 'array' function from `numpy`

import numpy
array([1,2,3])

# Note the error behavior here.
# `array()` is a function in the numpy package
# We need to be more specific about referencing that function

# %%
# Example - Importing Packages
# Use the 'array' function from `numpy`

numpy.array([1,2,3])
# Try print() with this. Are the outputs different?
print(numpy.array([1,2,3]))

# %%
# Example - Less Typing
import numpy as np
np.array([1,2,3])

# %%
# Example - Be more selecive

# If we want to use only one function from a package, we can just import that function
# If you do this, you do not need to numpy. (or np.) notation to reference the function
from numpy import array
array([1,2,3])

# %% [markdown]
# ### Which option is the best?
#
# - `import numpy` followed by `numpy.array()` is the clearest version in code, but requires more typing
# - `import numpy as np` followed by `np.array()` requires some human memory
# - `from numpy import array` followed by `array()` requires the least coding, but hides some detail (requires more human memory)
#
# The structure of `import numpy as np` is used very frequently. There are common shorthand names for many of the packages we'll see.

# %%
## Example - Pi
# Let's calculate the circumference and area of a circle with radius r=0.43.
# Circumference = 2*pi*r
# Area = pi*r^2

# The object `pi` doesn't exist in the main distribution of Python, but does exist in the `math` package
# Import the math package
import math

# Calculate C
C = 2 * 0.43 * math.pi

# Calculate A
A = pi * 0.43 ** 2  # `**` is used for exponentiation

print("Circumference: " + str(C))
print("Area: " + str(A))

# Why doesn't this work as it is currently?

# %%
# Example - Pi
#Common values (like pi) are reasonable objects to import directly

from math import pi
# Calculate C
C = 2 * 0.43 * pi

# Calculate A
A = pi * 0.43 ** 2  # `**` is used for exponentiation

print("Circumference: " + str(C))
print("Area: " + str(A))

# %% [markdown]
# ## Activity - Playing with Penguins
#
# Work in groups of 1-2 to complete the following excercise.

# %% [markdown]
# Start by running the commands below to import a coupld of packages and load in the penguin dataset.

# %%
import seaborn as sns
import numpy as np

penguins = sns.load_dataset('penguins')  # loads data a dataframe
print('rows, columns:', penguins.shape)
penguins.head()

# %% [markdown]
# Each row is one penguin (a *case*) and each column is a measured *feature*.
#
# A. Fill in the following code chunk to isolate the `flipper_length_mm` variable.
# Recall:
# - We refer to strings with single or double quotes: e.g. var = 'string name'

# %%
# FILL-IN
column_name =                    # <-- fill in

flippers = penguins[column_name].dropna().tolist()
# Note We use .dropna() to drop missing values before summarizing.
# Why might a real dataset have missing measurements, and what could go wrong
# if we forgot to drop them before computing a mean?
# (We handle missing data carefully in the EXPLORE unit.)
print(flippers)

# %% [markdown]
# B. Now explore the variable and create a summary statistic:

# %%
# FILL-IN
print('number of measurements:', _____ )
print('shortest:', _____ , ' longest:', _____ )
print('mean:', round( _____ , 1), 'mm')

# %% [markdown]
# C. How do Adelie and Gentoo penguins compare in body mass?
#
# Fill in the blanks, predict before running, and write your conclusion in the final comment.

# %%
# FILL-IN

# Pull body mass for each species, dropping missing values.
adelie = penguins[penguins['species'] == 'Adelie']['body_mass_g'].dropna().tolist()
gentoo = penguins[penguins['species'] == ____ ]['body_mass_g'].dropna().tolist()

# Compute each group's count and mean.
print('Adelie: n =', len(adelie), ' mean =', round(sum(adelie)/ _____ , 1))
print('Gentoo: n =', ____, ' mean =', round(sum(gentoo)/len(gentoo), 1))

# Our conclusion (write one sentence as a comment):
#
