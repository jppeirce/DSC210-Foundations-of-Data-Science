# %% [markdown]
# <a href="https://colab.research.google.com/github/jppeirce/DSC210-Foundations-of-Data-Science/blob/main/Homework/03-arrays_and_visualization/HW03-arrays_and_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 3: Seeing the Structure
#
# **DSC 210 Foundations of Data Science**
#
# *Covers Module 4, Section 2 (2D arrays, `axis`, correlation, z-scores) and Module 5 (data visualization with seaborn).*
#
# References:
# - Module 4 and Module 5 course notebooks
# - [Hands-on Introduction to Data Science with Python](https://florian-huber.github.io/data_science_course/) (CC BY-NC-SA 4.0)
#
# *Last major revision: 2026-08-04*
#
# ## Key Concepts
#
# - Organize data into a 2D array and summarize it along the correct `axis`
# - Compute and interpret a correlation, and recognize when a single number lies
# - Reproduce **Simpson's paradox** numerically, then draw the picture that explains it
# - Choose, build, and fully label an appropriate plot for a question
# - Use a log scale when a linear one hides the data
# - Write a **Professional Summary**: report a finding in the register a colleague would expect
#
# ---

# %% [markdown]
# ## Instructions
#
# **Total: 50 points.** Point values are listed with each problem.
#
# - Cells marked `# FILL-IN` contain blanks written as `____` and will raise a `SyntaxError` until every blank is replaced.
# - Where you are asked to produce a plot, **every figure must carry a title and labeled axes.** An unlabeled figure loses points no matter how good the code is.
# - Most of the credit in this assignment rides on your written interpretation, not on styling. Say what the picture shows.
# - Submit the completed `.ipynb`, with all cells run and all figures visible, to Canvas.

# %% [markdown]
# ---
# ## Part 0. Setup check (2 points)
# ---

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

penguins = sns.load_dataset('penguins')
planets  = sns.load_dataset('planets')

print('penguins shape:', penguins.shape)
print('planets shape :', planets.shape)
print('planets columns:', list(planets.columns))
# Out:
# penguins shape: (344, 7)
# planets shape : (1035, 6)
# planets columns: ['method', 'number', 'orbital_period', 'mass', 'distance', 'year']

# %% [markdown]
# **Problem 0.** (2 points) Report the two shapes and the `planets` column names printed above. If anything errored, paste the message.
#
# **Your answer:**

# %% [markdown]
# ---
# ## Part A. Short answer (12 points)
# ---

# %% [markdown]
# ### Problem A1. Reading a 2D array (3 points)
#
# Consider this array, where each **row** is a student and each **column** is an exam:
#
# ```python
# scores = np.array([[88, 92, 85],
#                    [79, 71, 90],
#                    [95, 98, 99],
#                    [62, 70, 74]])
# ```
#
# (a) What does `scores.shape` return? Which number counts students?
#
# (b) One of `scores.mean(axis=0)` and `scores.mean(axis=1)` returns the class average on each exam; the other returns each student's personal average. Say which is which, and give the number of values each returns.
#
# (c) `scores.mean()` with no `axis` returns a single number. Say what it means, and give one reason reporting it alone would be misleading.
#
# **Your answer:**
#
# (a)
#
# (b)
#
# (c)

# %% [markdown]
# ### Problem A2. What a correlation does and does not tell you (3 points)
#
# (a) For each, state whether you expect the correlation to be strongly positive, weakly positive, near zero, or negative:
#
# - a person's height and their shoe size
# - the age of a used car and its resale price
# - a student's phone number and their GPA
#
# (b) Two datasets both have r = 0.82. One is a tight straight line; the other is a curve with a single extreme outlier dragging the line. Which module example makes this point, and what does it tell you to do before trusting any r?
#
# (c) A correlation near zero means there is no *linear* association. Describe in words a relationship between two variables that is strong and obvious to the eye but would produce r near zero.
#
# **Your answer:**
#
# (a)
#
# (b)
#
# (c)

# %% [markdown]
# ### Problem A3. Choosing the plot (3 points)
#
# For each question, name the plot you would draw, the variable or variables it uses, and whether you would add `hue`.
#
# | # | Question |
# | --- | --- |
# | a | Is body mass roughly symmetric, or skewed? |
# | b | Do the three penguin species differ in flipper length, and which has the most spread? |
# | c | Does bill length rise with bill depth, and does the answer change by species? |
# | d | You were handed `planets` five minutes ago and know nothing about it. |
#
# **Your answer:**
#
# | # | Plot | Variable(s) | hue? |
# | --- | --- | --- | --- |
# | a |  |  |  |
# | b |  |  |  |
# | c |  |  |  |
# | d |  |  |  |

# %% [markdown]
# ### Problem A4. Reading a boxplot you did not make (3 points)
#
# A boxplot of exam scores shows: median 74, box from 66 to 82, whiskers reaching 51 and 97, and two points plotted separately at 38 and 41.
#
# (a) Report the five-number summary and the IQR.
#
# (b) Compute the lower fence, Q1 - 1.5 x IQR, and confirm that 38 and 41 fall below it.
#
# (c) Can you tell from this boxplot whether the scores between 66 and 82 have one peak or two? What plot would settle it?
#
# **Your answer:**
#
# (a)
#
# (b)
#
# (c)

# %% [markdown]
# ---
# ## Part B. Code completion (12 points)
# ---

# %% [markdown]
# ### Problem B1. Build and summarize a 2D array (4 points)

# %%
# RUN-TOGETHER  (setup for Problem B1)
p = penguins.dropna()
flipper = p['flipper_length_mm'].to_numpy()
mass_g  = p['body_mass_g'].to_numpy()
print('n =', len(flipper))

# %%
# FILL-IN  (Problem B1)
# (a) Build features-as-rows, then transpose to subjects-as-rows.
M = np.array([flipper, mass_g])
D = M.____
print('M.shape =', M.shape, '  D.shape =', D.shape)

# (b) Mean of EACH feature (one flipper answer, one mass answer).
print('feature means:', np.round(D.mean(axis=____), 2))

# (c) The row of the heaviest penguin, and that penguin's flipper length.
i = np.argmax(D[:, 1])
print('heaviest row:', D[i], ' flipper:', D[i, ____])

# (d) Mean flipper length among penguins heavier than 4500 g.
row_mask = D[:, 1] > 4500
print('mean flipper of heavy penguins:', round(D[row_mask, ____].mean(), 2))

# %% [markdown]
# In one sentence: why did we transpose? What would `D.mean(axis=0)` have returned if we had not?
#
# **Your answer:**

# %% [markdown]
# ### Problem B2. z-scores (4 points)

# %%
# FILL-IN  (Problem B2)
mass = penguins['body_mass_g'].dropna().to_numpy()

# (a) Standardize to z-scores.
z = (mass - mass.mean()) / ____

# (b) Check the construction.
print('z mean:', round(z.mean(), 10), '| z std:', round(z.std(), 10))

# (c) Flag penguins more than 2 standard deviations from the mean.
unusual = mass[np.abs(z) ____ 2]
print('unusual penguins:', unusual.size)
print('their masses:', np.sort(unusual))

# %% [markdown]
# A z-score measures distance from the mean **of whatever sample you gave it**. Given what you know about the three species, name one risk of flagging outliers this way on the pooled data.
#
# **Your answer:**

# %% [markdown]
# ### Problem B3. A labeled figure (4 points)

# %%
# FILL-IN  (Problem B3)
# (a) Histogram of body mass, colored by species.
sns.histplot(data=penguins, x=____, hue=____)
plt.title(____)
plt.xlabel('Body mass (g)')
plt.ylabel('Count')
plt.show()

# %%
# FILL-IN  (Problem B3 continued)
# (b) Boxplot of body mass across species.
sns.boxplot(data=penguins, x=____, y=____)
plt.title(____)
plt.xlabel('Species')
plt.ylabel('Body mass (g)')
plt.show()

# %% [markdown]
# (c) Your two figures show the same data. Name one thing the histogram shows that the boxplot cannot, and one thing the boxplot shows more clearly.
#
# **Your answer:**

# %% [markdown]
# ---
# ## Part C. Guided coding (12 points)
# ---

# %% [markdown]
# ### Problem C1. Simpson's paradox: compute it, then draw it (6 points)
#
# In Module 4 you computed a correlation that reversed sign when the species were pooled. You never drew the picture. Do both here.
#
# (a) (2 points) In the cell below, compute the correlation between `bill_length_mm` and `bill_depth_mm` **pooled across all penguins**, and then **within each species separately**. Print all four numbers, rounded to 3 decimals. Work from `p` (the dropna'd table from Problem B1).

# %%
# Problem C1(a): your code here

# %% [markdown]
# (b) (2 points) Now draw the picture that explains those numbers: a scatterplot of bill length against bill depth, colored by species, fully labeled.

# %%
# Problem C1(b): your code here

# %% [markdown]
# (c) (2 points) Using your figure, explain the reversal. Your answer should say what each species cluster looks like on its own, and what happens to the trend when someone draws a single line through all three clusters at once. Name the phenomenon.
#
# **Your answer:**
#
# (c)

# %% [markdown]
# ### Problem C2. First contact with a new dataset (6 points)
#
# You have never seen the `planets` dataset before. It records confirmed exoplanet discoveries: the detection `method`, the `number` of planets known in that system, the `orbital_period` in days, the planet `mass` in Jupiter masses, the `distance` from Earth in parsecs, and the discovery `year`.
#
# (a) (2 points) Write code to report: the shape, how many missing values each column has, and how many distinct detection methods appear.

# %%
# Problem C2(a): your code here

# %% [markdown]
# (b) (2 points) Draw a histogram of `orbital_period` on a **linear** x-axis, then a second one on a **log** x-axis. Label both. (For the log version, `sns.histplot` accepts `log_scale=True`.)

# %%
# Problem C2(b): your code here

# %% [markdown]
# (c) (2 points) The linear histogram is nearly unreadable. Explain why, using the actual range of `orbital_period`, and say what the log version lets you see that the linear one hides. Then connect this to Module 5's Gapminder example: what did the log axis do there?
#
# **Your answer:**
#
# (c)

# %% [markdown]
# ---
# ## Part D. Application (12 points)
# ---

# %% [markdown]
# ### Problem D1. Which method finds which planets? (6 points)
#
# Different detection methods are sensitive to different kinds of planet. That is not a flaw in the data; it is physics, and it shows up as structure in the plot.
#
# (a) (2 points) Restrict to the four most common detection methods. Then draw a scatterplot of `mass` against `orbital_period`, colored by `method`, with **both axes on a log scale**, fully labeled.
#
# *Hint:* `planets['method'].value_counts().head(4).index` gives you the four most common methods, and `.isin(...)` filters to them. For log axes on a scatterplot, use `plt.xscale('log')` and `plt.yscale('log')`.

# %%
# Problem D1(a): your code here

# %% [markdown]
# (b) (2 points) Describe the structure. Do the methods overlap, or does each occupy its own region? Name one method and the corner of the plot it lives in.
#
# (c) (2 points) Here is the important question. Suppose someone computes the average mass of all known exoplanets and reports it as "the typical planet mass in the galaxy." Using your figure, explain why that number would be badly wrong. Your answer should use the word *sample* and should connect to the Module 4 idea that a single number computed over a mixed population can mislead.
#
# **Your answer:**
#
# (b)
#
# (c)

# %% [markdown]
# ### Problem D2. COMMUNICATE: one figure and a Professional Summary (6 points)
#
# Everything so far has been EXPLORE. This problem is the last stage of the loop.
#
# ```
# ASK  ->  GET  ->  EXPLORE  ->  MODEL  -> [ COMMUNICATE ]
# ```
#
# **Your task.** Choose **one** question you can answer with either `penguins` or `planets`. Produce the **single best figure** that answers it, and write a Professional Summary reporting the finding.
#
# Some questions worth asking, though you are encouraged to invent your own:
#
# - Which two measurements separate the penguin species most cleanly?
# - Has the typical mass of newly discovered planets changed over time?
# - Do the sexes differ in size within a single penguin species?
# - Which detection method has dominated in recent years?
#
# **(a) (1 point) State your question** in one sentence, precise enough that data could settle it.
#
# **Your question:**
#
#
# **(b) (2 points) The figure.** One figure with a title, labeled axes with units, and a legend if you use `hue`.

# %%
# Problem D2(b): your figure here

# %% [markdown]
# **(c) (3 points) The Professional Summary.**
#
# Write **3 to 5 sentences** reporting your finding as you would to a colleague who has not seen your code. A Professional Summary states what was measured, what was found (with specific numbers), and what the limits of the finding are. It does not narrate your process, and it never says "as you can see in the figure."
#
# Here is the register to aim for, from a summary of a bacterial growth experiment:
#
# > *Successive density measurements yielded an estimated discrete growth factor of R = 1.753, leading to an exponential growth model with an effective per-minute growth rate of 1.0357. The model accurately describes early-phase growth at low densities but fails to remain realistic at higher densities, highlighting the need for density-dependent refinements for long-term prediction.*
#
# Notice the shape: **what was measured, what was found with numbers, where it breaks down.** Your last sentence should name a genuine limitation, and "more data would help" is not one.
#
# **Your Professional Summary:**
