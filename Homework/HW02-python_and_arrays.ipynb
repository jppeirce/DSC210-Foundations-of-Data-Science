# %% [markdown]
# <a href="https://colab.research.google.com/github/jppeirce/DSC210-Foundations-of-Data-Science/blob/main/Homework/HW02-python_and_arrays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 2: Python Foundations and NumPy Arrays
#
# **DSC 210 Foundations of Data Science**
#
# *Covers Module 3 (Introduction to Python) and Module 4, Section 1 (arrays, broadcasting, and boolean masks).*
#
# References:
# - Module 3 and Module 4 course notebooks
# - [Hands-on Introduction to Data Science with Python](https://florian-huber.github.io/data_science_course/) (CC BY-NC-SA 4.0)
# - `penguins` and `titanic` datasets, included with the `seaborn` package
#
# *Last major revision: 2026-07-30*
#
# ## Key Concepts
#
# - Predict the type and value of Python expressions before running them
# - Index, slice, and safely copy lists
# - Explain why lists fail for element-wise math and arrays succeed
# - Use broadcasting and boolean masks to ask questions of real data
# - Choose the right denominator, because a fraction is only as honest as what it is out of

# %% [markdown]
# ## Instructions
#
# **Total: 50 points.** Point values are listed with each problem.
#
# - Answer written questions in the markdown cells marked **Your answer:**.
# - Cells marked `# FILL-IN` contain blanks written as `____` and will raise a `SyntaxError` until every blank is replaced. That error is expected until you finish the problem.
# - Several problems ask you to **predict before you run**. Write the prediction down first. A wrong prediction costs nothing; a missing one does.
# - Unlike Homework 1, this assignment asks you to **write and modify code yourself**. Everything you need appeared in Modules 3 and 4.
# - Submit the completed `.ipynb` file, with all cells run, to Canvas.

# %% [markdown]
# ---
# ## Part 0. Setup check (2 points)
# ---
#
# Run the cell below. It loads the packages and both datasets used in this assignment.

# %%
import seaborn as sns
import numpy as np

penguins = sns.load_dataset('penguins')
titanic  = sns.load_dataset('titanic')

print('numpy version :', np.__version__)
print('penguins shape:', penguins.shape)
print('titanic shape :', titanic.shape)

# %% [markdown]
# **Problem 0.** (2 points) Did the cell run without an error? If yes, report the two shapes it printed. If no, paste the error message.
#
# **Your answer:**

# %% [markdown]
# ---
# ## Part A. Short answer (12 points)
# ---

# %% [markdown]
# ### Problem A1. Predict type and value (3 points)
#
# For each expression, state the **type** of the result and the **value**, or state that it raises an error. Do this *without* running code first; you may check afterward and note any you got wrong.
#
# | # | Expression | Type | Value (or error) |
# | --- | --- | --- | --- |
# | a | `15 / 3` |  |  |
# | b | `15 * 4` |  |  |
# | c | `'DSC' + '210'` |  |  |
# | d | `'DSC' + 210` |  |  |
# | e | `(3 > 5)` |  |  |
# | f | `True + True + False` |  |  |
#
# **Your answer:** *(fill in the table above, and note below which ones surprised you when you checked)*

# %% [markdown]
# ### Problem A2. Indexing and slicing (3 points)
#
# A list holds the daily closing price of a stock for one trading week, Monday through Friday:
#
# ```python
# prices = [102.5, 101.0, 104.2, 103.8, 106.1]
# ```
#
# (a) Write the expression that returns Wednesday's price.
#
# (b) Write the expression that returns Thursday and Friday as a list.
#
# (c) A classmate writes `prices[1:2]` expecting Monday and Tuesday. They have made **two** distinct mistakes. Identify both.
#
# **Your answer:**
#
# (a)
#
# (b)
#
# (c)

# %% [markdown]
# ### Problem A3. The silent bug (3 points)
#
# Consider this code, which runs without any error:
#
# ```python
# raw_data = [4.2, 5.1, 3.9, 4.8]
# cleaned = raw_data
# cleaned.append(0.0)
# ```
#
# (a) After the third line, what does `raw_data` contain? Explain why in one sentence.
#
# (b) Rewrite the second line so that `raw_data` is protected.
#
# (c) Module 2 showed a *loud* failure (the `TypeError` from averaging species) and a *silent* one (the meaningless mean of `pclass`). Which kind is this, and why does that make it the more dangerous of the two for a data scientist?
#
# **Your answer:**
#
# (a)
#
# (b)
#
# (c)

# %% [markdown]
# ### Problem A4. Lists versus arrays (3 points)
#
# (a) Predict the output of each line:
#
# ```python
# [70, 80, 90] + [70, 80, 90]
# np.array([70, 80, 90]) + np.array([70, 80, 90])
# ```
#
# (b) A NumPy array can hold only one type. Predict what `np.array([True, 2, 3.5])` contains, and what `np.array([1, 2, 'three'])` contains.
#
# (c) In one or two sentences: why is the array behavior in (a) the behavior a data scientist usually wants? Use the phrase "element-wise" in your answer.
#
# **Your answer:**
#
# (a)
#
# (b)
#
# (c)

# %% [markdown]
# ---
# ## Part B. Code completion (12 points)
# ---
# Each problem is one `# FILL-IN` cell. Replace every `____`, run the cell, and make sure the output makes sense before moving on.

# %% [markdown]
# ### Problem B1. Summarizing a list (4 points)
#
# A field team measured the body masses, in grams, of eight penguins.

# %%
# FILL-IN  (Problem B1)
masses = [3750, 3800, 3250, 3700, 3450, 3650, 3800, 5700]

# (a) the number of penguins in the sample
print('count   :', ____)

# (b) the lightest and heaviest
print('lightest:', ____)
print('heaviest:', ____)

# (c) the mean mass, rounded to 1 decimal place
print('mean    :', round(____ / ____, 1))

# (d) the first three penguins, as a list
print('first 3 :', masses[____])

# %% [markdown]
# One penguin is far heavier than the rest. In one sentence: does removing it change the mean or the median more, and why?
#
# **Your answer:**

# %% [markdown]
# ### Problem B2. Broadcasting (4 points)
#
# The cell below pulls flipper lengths from the penguins dataset as a NumPy array.

# %%
# FILL-IN  (Problem B2)
flippers_mm = penguins['flipper_length_mm'].dropna().to_numpy()

# (a) convert every measurement from millimeters to centimeters, 
# using broadcasting
flippers_cm = ____
print('first five (cm):', flippers_cm[:5])

# (b) how many flipper measurements are there?
print('count:', ____)

# (c) mean flipper length in cm, rounded to 2 decimal places
print('mean (cm):', round(____, 2))

# %% [markdown]
# Explain in one sentence what *broadcasting* did in part (a), without using the word "loop."
#
# **Your answer:**

# %% [markdown]
# ### Problem B3. Boolean masks (4 points)

# %%
# FILL-IN  (Problem B3)
mass_g = penguins['body_mass_g'].dropna().to_numpy()

# (a) a boolean mask for penguins over 4000 g
big = ____
print('first five of the mask:', big[:5])

# (b) how many penguins are over 4000 g?
print('count over 4000 g:', ____)

# (c) the fraction of all penguins over 4000 g
#     (recall: the mean of a boolean array is a proportion)
print('fraction:', round(____, 3))

# (d) the mean mass of ONLY the penguins over 4000 g
print('mean of the big ones:', round(mass_g[____].mean(), 1))

# %% [markdown]
# Parts (c) and (d) both use the mask, but they answer different questions. State each question in plain English.
#
# **Your answer:**

# %% [markdown]
# ---
# ## Part C. Guided coding (12 points)
# ---
# Now you write the code. Every tool you need appeared in Modules 3 and 4.

# %% [markdown]
# ### Problem C1. Children aboard the Titanic (6 points)
#
# Homework 1 asked you to *read* the titanic data. Now you can *query* it.
#
# Write code in the cell below to answer all four parts. Use comments to label which part each line answers.
#
# (a) Pull the `age` column into a NumPy array called `ages`, dropping missing values first (the Module 4 pattern: `.dropna().to_numpy()`).
#
# (b) Report how many passengers have a recorded age, and the mean age rounded to 1 decimal place.
#
# (c) Using a boolean mask, report how many passengers were children (under 18), and what fraction of passengers with a recorded age that represents.
#
# (d) Report the mean age of the children only.

# %%
# Problem C1: your code here

# %% [markdown]
# (e) In Homework 1 you found that about 177 passengers have no recorded age. Your fraction in (c) is therefore a fraction *of passengers with a recorded age*, not of everyone aboard. Give one plausible reason the missing ages might not be spread evenly across passengers, and say which direction that could bias your estimate of the fraction of children.
#
# **Your answer:**

# %% [markdown]
# ### Problem C2. Two species, one question (6 points)
#
# Are Gentoo penguins heavier than Adelie penguins? Answer with arrays and masks.
#
# (a) Build a NumPy array of body masses and a matching array of species names. Start from `penguins.dropna()` so the two arrays line up row for row.
#
# (b) Build boolean masks `adelie` and `gentoo` from the species array.
#
# (c) Report the count and mean mass for each species, with the means rounded to 1 decimal place.
#
# (d) Report the difference between the two means.

# %%
# Problem C2: your code here

# %% [markdown]
# (e) Write your conclusion as one sentence a non-programmer could read. Then, in a second sentence, name one thing your comparison does **not** establish. Module 4's warning about pooled comparisons is relevant: sex also affects mass, and you have not controlled for it.
#
# **Your answer:**

# %% [markdown]
# ---
# ## Part D. Application (12 points)
# ---

# %% [markdown]
# ### Problem D1. Who survived? (6 points)
#
# The `titanic` dataset records `survived` as 0 or 1, and `sex` as `'male'` or `'female'`. Because the mean of a 0/1 array is a proportion, boolean masks let you compute survival rates directly.
#
# (a) (3 points) Write code to report three numbers: the overall survival rate, the survival rate among women, and the survival rate among men. Round each to 3 decimal places. (Pull the columns with `.to_numpy()`; there are no missing values in these two columns.)

# %%
# Problem D1(a): your code here

# %% [markdown]
# (b) (1 point) Also compute: *among the survivors*, what fraction were women? (Mask to survivors first, then ask about sex.)
#
# (c) (2 points) The number in (b) and the survival rate among women are different questions with different denominators. A journalist writes: "Most survivors were women, so being a woman nearly guaranteed survival." Using your numbers, explain what the journalist got right and what they got wrong. Name the denominator of each claim.
#
# **Your answer:**
#
# (b)
#
# (c)

# %% [markdown]
# ### Problem D2. Which mean answers the question? (6 points)
#
# A weather station records daily rainfall, in millimeters, for three weeks:
#
# ```python
# rain = np.array([0, 0, 3.2, 11.4, 0, 0.6, 0,
#                  0, 0, 22.1, 4.5, 0, 0, 1.1,
#                  0, 8.3, 0, 0, 2.7, 0, 0])
# ```
#
# (a) (3 points) Write code to compute: the number of rainy days (rainfall greater than 0), the fraction of days that were rainy, the mean rainfall over **all** days, and the mean rainfall over **rainy days only**. Round the means to 2 decimal places.

# %%
# Problem D2(a): your code here

# %% [markdown]
# (b) (1 point) A town planner asks: "How much water does this area receive over time?" A hiker asks: "If it rains on my trip, how wet will I get?" Match each person to the mean that answers their question.
#
# (c) (2 points) A report states "average daily rainfall was 2.57 mm" with no other context. Using Module 2's data - information - knowledge progression, explain why this number, by itself, is data rather than information, and state the minimum context that would promote it.
#
# **Your answer:**
#
# (b)
#
# (c)
